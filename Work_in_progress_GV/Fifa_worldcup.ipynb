# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import os
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pd.read_csv('../Project Reference Materials/fifa_world_cup.csv')
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
SELECT home_team
# Out:
#   Cell In[9], line 1
#     SELECT home_team
#            ^
# SyntaxError: invalid syntax

# %%
SELECT date
# Out:
#   Cell In[11], line 1
#     SELECT date
#            ^
# SyntaxError: invalid syntax

# %%
SELECT chile
# Out:
#   Cell In[13], line 1
#     SELECT chile
#            ^
# SyntaxError: invalid syntax

# %%
SELECT Chile 
FROM home_team
# Out:
#   Cell In[15], line 1
#     SELECT Chile
#            ^
# SyntaxError: invalid syntax

# %%
pd.read_csv('../Project Reference Materials/fifa_world_cup.csv
# Out:
#   Cell In[17], line 1
#     pd.read_csv('../Project Reference Materials/fifa_world_cup.csv
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
pd.read_csv('../Project Reference Materials/fifa_world_cup.csv')
            SELECT home_team
            FROM Chile
# Out:
#   Cell In[19], line 2
#     SELECT home_team
#     ^
# IndentationError: unexpected indent

# %%
pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv
            SELECT home_team
            FROM Chile""")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv
#       2             SELECT home_team
#       3             FROM Chile""")
#
# ...

# %%
pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv; 
            SELECT home_team
            FROM Chile""")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv;
#       2             SELECT home_team
#       3             FROM Chile""")
#
# ...

# %%
pd.read_csv('../Project Reference Materials/fifa_world_cup.csv')
SELECT Chile
FROM home_team
# Out:
#   Cell In[25], line 2
#     SELECT Chile
#            ^
# SyntaxError: invalid syntax

# %%
pd.read_csv('../Project Reference Materials/fifa_world_cup.csv')
SELECT 'Chile'
FROM home_team
# Out:
#   Cell In[27], line 2
#     SELECT 'Chile'
#            ^
# SyntaxError: invalid syntax

# %%
pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv')
SELECT Chile
FROM home_team""", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv')
#       2 SELECT Chile
# ----> 3 FROM home_team""", conn)
#
# NameError: name 'conn' is not defined

# %%
pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv')
SELECT Chile
FROM home_team""");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv')
#       2 SELECT Chile
#       3 FROM home_team""")
#
# ...

# %%
pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv'/
SELECT Chile
FROM home_team""");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv'/
#       2 SELECT Chile
#       3 FROM home_team""")
#
# ...

# %%
pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv-
SELECT Chile FROM home_team""")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv-
#       2 SELECT Chile FROM home_team""")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv/..
SELECT Chile FROM home_team""")
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv/..
#       2 SELECT Chile FROM home_team""")
#
# ...

# %%
pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv, 
SELECT Chile FROM home_team""")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 pd.read_csv("""../Project Reference Materials/fifa_world_cup.csv,
#       2 SELECT Chile FROM home_team""")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
>>> pd.read_csv('../Project Reference Materials/fifa_world_cup.csv')
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
SELECT chile FROM home_team
# Out:
#   Cell In[83], line 1
#     SELECT chile FROM home_team
#            ^
# SyntaxError: invalid syntax

# %%
>>> pd.read_csv('../Project Reference Materials/fifa_world_cup.csv')
# Out:
#   Cell In[85], line 1
#     pd.read_csv('../Project Reference Materials/fifa_world_cup.csv'), SELECT chile FROM home_team
#                                                                              ^
# SyntaxError: invalid syntax

# %%
>>> pd.read_csv('../Project Reference Materials/fifa_world_cup.csv')
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
>>> pd.read_csv """../Project Reference Materials/fifa_world_cup.csv"""
# Out:
#   Cell In[89], line 1
#     pd.read_csv """../Project Reference Materials/fifa_world_cup.csv"""
#                 ^
# SyntaxError: invalid syntax

# %%
fifa_ds = pd.read_csv('../Project Reference Materials/fifa_world_cup.csv')

# %%
fifa_ds
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
fifa_ds['home_team']
# Out:
# 0               Bolivia
# 1                Brazil
# 2               Ecuador
# 3                Guinea
# 4              Paraguay
#               ...
# 23916           Moldova
# 23917     Liechtenstein
# 23918             Chile
# 23919             Japan
# 23920    Korea Republic
# Name: home_team, Length: 23921, dtype: object

# %%
fifa_ds['home_team']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 fifa_ds['home_team']:chile
#
# NameError: name 'chile' is not defined

# %%
fifa_ds['home_team_fifa_rank']
# Out:
# 0         59
# 1          8
# 2         35
# 3         65
# 4         67
#         ...
# 23916    180
# 23917    192
# 23918     28
# 23919     23
# 23920     29
# Name: home_team_fifa_rank, Length: 23921, dtype: int64

# %%
fifa_ds['home_team_result']
# Out:
# 0         Win
# 1        Draw
# 2         Win
# 3         Win
# 4        Lose
#          ...
# 23916     Win
# 23917    Lose
# 23918    Lose
# 23919    Lose
# 23920     Win
# Name: home_team_result, Length: 23921, dtype: object

# %%
fifa_ds['home_team','home_team_result']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('home_team', 'home_team_result')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ...

# %%
fifa_ds.describe('home_team')
# Out:
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# count         23921.000000         23921.000000                 23921.000000
# mean             77.854688            80.797375                   323.401488
# std              52.355225            53.232902                   500.825725
# min               1.000000             1.000000                     0.000000
# 25%              33.000000            36.000000                     0.000000
# 50%              71.000000            73.000000                     0.000000
# 75%             115.000000           119.000000                   547.000000
# max             211.000000           211.000000                  2164.000000
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# count                 23921.000000     23921.000000     23921.000000
# mean                    315.453576         1.609214         1.068266
# ...

# %%
fifa_ds.describe('home_team_fifa_rank')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 fifa_ds.describe('home_team_fifa_rank')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
fifa_ds.describe['home_team)t']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 fifa_ds.describe['home_team']
#
# TypeError: 'method' object is not subscriptable

# %%
fifa_ds
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
fifa_ds.shape
# Out:
# (23921, 25)

# %%
fifa_ds.loc[:,['home_team', 'home_team_fifa_rank', 'home_team_total_fifa_points']]
# Out:
#             home_team  home_team_fifa_rank  home_team_total_fifa_points
# 0             Bolivia                   59                            0
# 1              Brazil                    8                            0
# 2             Ecuador                   35                            0
# 3              Guinea                   65                            0
# 4            Paraguay                   67                            0
# ...               ...                  ...                          ...
# 23916         Moldova                  180                          932
# 23917   Liechtenstein                  192                          895
# 23918           Chile                   28                         1526
# 23919           Japan                   23                         1553
# 23920  Korea Republic                   29                         1519
#
# [23921 rows x 3 columns]

# %%
fifa_ds.loc[:,['home_team', 'home_team_fifa_rank', 'home_team_total_fifa_points']]
# Out:
#   Cell In[139], line 1
#     fifa_ds.loc[:,['home_team', 'home_team_fifa_rank', 'home_team_total_fifa_points']] Count
#                                                                                        ^
# SyntaxError: invalid syntax

# %%
sns.set_style('darkgrid')
sns.distplot(a=fifa_ds['home_team_fifa_rank']);
# Out:
# /var/folders/d7/28f1tlx911l17_drdhrd1kp40000gn/T/ipykernel_73252/3011730583.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=fifa_ds['home_team_fifa_rank']);

# %%
sns.set_style('darkgrid')
sns.distplot(a=fifa_ds['away_team_fifa_rank']);
# Out:
# /var/folders/d7/28f1tlx911l17_drdhrd1kp40000gn/T/ipykernel_73252/1279352297.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=fifa_ds['away_team_fifa_rank']);

# %%
sns.set_style('scatterplot')
sns.scatterplot(a=fifa_ds['away_team_fifa_rank']);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 sns.set_style('scatterplot')
#       2 sns.scatterplot(a=fifa_ds['away_team_fifa_rank'])
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/rcmod.py:331, in set_style(style, rc)
#     303 def set_style(style=None, rc=None):
#     304     """
#     305     Set the parameters that control the general style of the plots.
#     306
#    (...)
#     329
#     330     """
# --> 331     style_object = axes_style(style, rc)
#     332     mpl.rcParams.update(style_object)
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/rcmod.py:185, in axes_style(style, rc)
#     183 styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
#     184 if style not in styles:
# --> 185     raise ValueError(f"style must be one of {', '.join(styles)}")
#     187 # Define colors here
# ...

# %%
sns.scatterplot(y=fifa_ds['home_team_fifa_rank'], x=fifa_ds['home_team_total_fifa_points']);

# %%
sns.scatterplot(y=fifa_ds['home_team_goalkeeper_score'], x=fifa_ds['home_team_total_fifa_points']);

# %%
sns.scatterplot(y=fifa_ds['home_team_goalkeeper_score'], x=fifa_ds['home_team_fifa_rank']);

# %%
sns.scatterplot(y=fifa_ds['home_team_goalkeeper_score'], x=fifa_ds['home_team_result']);

# %%
sns.scatterplot(y=fifa_ds['away_team_goalkeeper_score'], x=fifa_ds['away_team_result']);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'away_team_result'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[187], line 1
# ...
